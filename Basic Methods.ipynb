# %%
import pandas as pd
import numpy as np

# %%
fichero = 'C:\Proyectos\Scripting-Data-science\Data1\\test-data.csv'

# %%
datos = pd.read_csv(fichero)

# %%
print(datos.dtypes)
# Out:
# Unnamed: 0             int64
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# dtype: object

# %%
datos
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
datos.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1234.000000  1234.000000        1234.000000  1223.000000
# mean    616.500000  2013.400324       58507.288493     5.284546
# std     356.369424     3.179700       35598.702098     0.825622
# min       0.000000  1996.000000        1000.000000     2.000000
# 25%     308.250000  2011.000000       34000.000000     5.000000
# 50%     616.500000  2014.000000       54572.500000     5.000000
# 75%     924.750000  2016.000000       75000.000000     5.000000
# max    1233.000000  2019.000000      350000.000000    10.000000

# %%
datos.describe(include='all')
# Out:
#          Unnamed: 0             Name Location         Year  Kilometers_Driven  \
# count   1234.000000             1234     1234  1234.000000        1234.000000
# unique          NaN              768       11          NaN                NaN
# top             NaN  Maruti Alto LXi   Mumbai          NaN                NaN
# freq            NaN                9      159          NaN                NaN
# mean     616.500000              NaN      NaN  2013.400324       58507.288493
# std      356.369424              NaN      NaN     3.179700       35598.702098
# min        0.000000              NaN      NaN  1996.000000        1000.000000
# 25%      308.250000              NaN      NaN  2011.000000       34000.000000
# 50%      616.500000              NaN      NaN  2014.000000       54572.500000
# 75%      924.750000              NaN      NaN  2016.000000       75000.000000
# max     1233.000000              NaN      NaN  2019.000000      350000.000000
#
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1234 non-null   int64
#  1   Name               1234 non-null   object
#  2   Location           1234 non-null   object
#  3   Year               1234 non-null   int64
#  4   Kilometers_Driven  1234 non-null   int64
#  5   Fuel_Type          1234 non-null   object
#  6   Transmission       1234 non-null   object
#  7   Owner_Type         1234 non-null   object
#  8   Mileage            1234 non-null   object
#  9   Engine             1224 non-null   object
#  10  Power              1224 non-null   object
#  11  Seats              1223 non-null   float64
#  12  New_Price          182 non-null    object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 125.5+ KB

# %%
datos['Seats'].head(5)
# Out:
# 0    4.0
# 1    5.0
# 2    7.0
# 3    5.0
# 4    5.0
# Name: Seats, dtype: float64

# %%
datos['Seats'] = datos['Seats'] + 1

# %%
datos['Seats'].head(5)
# Out:
# 0    5.0
# 1    6.0
# 2    8.0
# 3    6.0
# 4    6.0
# Name: Seats, dtype: float64

# %%
datos.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1234.000000  1234.000000        1234.000000  1223.000000
# mean    616.500000  2013.400324       58507.288493     6.284546
# std     356.369424     3.179700       35598.702098     0.825622
# min       0.000000  1996.000000        1000.000000     3.000000
# 25%     308.250000  2011.000000       34000.000000     6.000000
# 50%     616.500000  2014.000000       54572.500000     6.000000
# 75%     924.750000  2016.000000       75000.000000     6.000000
# max    1233.000000  2019.000000      350000.000000    11.000000

# %%
datos.dropna(subset=['Seats'],axis=0,inplace=True)

# %%
datos.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1223.000000  1223.000000        1223.000000  1223.000000
# mean    616.365495  2013.412101       58423.957482     6.284546
# std     357.273918     3.177548       35565.435199     0.825622
# min       0.000000  1996.000000        1000.000000     3.000000
# 25%     306.500000  2011.000000       34000.000000     6.000000
# 50%     615.000000  2014.000000       54407.000000     6.000000
# 75%     926.500000  2016.000000       75000.000000     6.000000
# max    1233.000000  2019.000000      350000.000000    11.000000

# %%
datos.replace(np.nan, 'nulo')
# Out:
#       Unnamed: 0                                               Name  \
# 0              0                            Maruti Alto K10 LXI CNG
# 1              1                      Maruti Alto 800 2016-2019 LXI
# 2              2          Toyota Innova Crysta Touring Sport 2.4 MT
# 3              3                               Toyota Etios Liva GD
# 4              4                                  Hyundai i20 Magna
# ...          ...                                                ...
# 1229        1229                  Volkswagen Vento Diesel Trendline
# 1230        1230                             Volkswagen Polo GT TSI
# 1231        1231                             Nissan Micra Diesel XV
# 1232        1232                             Volkswagen Polo GT TSI
# 1233        1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
#
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# ...

# %%
datos.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1223.000000  1223.000000        1223.000000  1223.000000
# mean    616.365495  2013.412101       58423.957482     6.284546
# std     357.273918     3.177548       35565.435199     0.825622
# min       0.000000  1996.000000        1000.000000     3.000000
# 25%     306.500000  2011.000000       34000.000000     6.000000
# 50%     615.000000  2014.000000       54407.000000     6.000000
# 75%     926.500000  2016.000000       75000.000000     6.000000
# max    1233.000000  2019.000000      350000.000000    11.000000

# %%
media_asientos = datos['Seats'].mean()

# %%
media_asientos
# Out:
# 6.28454619787408

# %%
datos.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1223.000000  1223.000000        1223.000000  1223.000000
# mean    616.365495  2013.412101       58423.957482     6.284546
# std     357.273918     3.177548       35565.435199     0.825622
# min       0.000000  1996.000000        1000.000000     3.000000
# 25%     306.500000  2011.000000       34000.000000     6.000000
# 50%     615.000000  2014.000000       54407.000000     6.000000
# 75%     926.500000  2016.000000       75000.000000     6.000000
# max    1233.000000  2019.000000      350000.000000    11.000000

# %%
datos['Seats'].replace('nulo', media_asientos, inplace=True)

# %%
datos.describe()
# Out:
#         Unnamed: 0         Year  Kilometers_Driven        Seats
# count  1223.000000  1223.000000        1223.000000  1223.000000
# mean    616.365495  2013.412101       58423.957482     6.284546
# std     357.273918     3.177548       35565.435199     0.825622
# min       0.000000  1996.000000        1000.000000     3.000000
# 25%     306.500000  2011.000000       34000.000000     6.000000
# 50%     615.000000  2014.000000       54407.000000     6.000000
# 75%     926.500000  2016.000000       75000.000000     6.000000
# max    1233.000000  2019.000000      350000.000000    11.000000

# %%
datos['Seats'] > 5
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1229     True
# 1230     True
# 1231     True
# 1232     True
# 1233     True
# Name: Seats, Length: 1223, dtype: bool
