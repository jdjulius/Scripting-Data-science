# %% [markdown]
# ### Imports

# %%
import pandas as pd

# %%
fichero = 'C:\Proyectos\Scripting-Data-science\Data1\\test-data.csv'

# %%
datos = pd.read_csv(fichero)

# %%
datos
# Out:
#         id                                               Name    Location  \
# 0        0                            Maruti Alto K10 LXI CNG       Delhi
# 1        1                      Maruti Alto 800 2016-2019 LXI  Coimbatore
# 2        2          Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai
# 3        3                               Toyota Etios Liva GD   Hyderabad
# 4        4                                  Hyundai i20 Magna      Mumbai
# ...    ...                                                ...         ...
# 1229  1229                  Volkswagen Vento Diesel Trendline   Hyderabad
# 1230  1230                             Volkswagen Polo GT TSI      Mumbai
# 1231  1231                             Nissan Micra Diesel XV     Kolkata
# 1232  1232                             Volkswagen Polo GT TSI        Pune
# 1233  1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  \
# ...

# %%
datos.head(5)
# Out:
#    id                                       Name    Location  Year  \
# 0   0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1   1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2   2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3   3                       Toyota Etios Liva GD   Hyderabad  2012
# 4   4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats   New_Price
# 0   58.2 bhp    4.0         NaN
# 1   47.3 bhp    5.0         NaN
# ...

# %%
datos.tail(5)
# Out:
#         id                                               Name   Location  \
# 1229  1229                  Volkswagen Vento Diesel Trendline  Hyderabad
# 1230  1230                             Volkswagen Polo GT TSI     Mumbai
# 1231  1231                             Nissan Micra Diesel XV    Kolkata
# 1232  1232                             Volkswagen Polo GT TSI       Pune
# 1233  1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 1229  2011              89411    Diesel       Manual      First  20.54 kmpl
# 1230  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 1231  2012              28000    Diesel       Manual      First  23.08 kmpl
# 1232  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 1233  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price
# ...

# %%
datos.columns
# Out:
# Index(['id', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price'],
#       dtype='object')

# %%
titulos = ['id', 'nombre', 'localizacion', 'año', 'kilometraje', 'tipo de gas', 'transmision', 'tipo dueño', 'millage', 'motor', 'poder', 'asientos','precio']
datos.columns = titulos

# %%
datos.head(5)
# Out:
#    id                                     nombre localizacion   año  \
# 0   0                    Maruti Alto K10 LXI CNG        Delhi  2014
# 1   1              Maruti Alto 800 2016-2019 LXI   Coimbatore  2013
# 2   2  Toyota Innova Crysta Touring Sport 2.4 MT       Mumbai  2017
# 3   3                       Toyota Etios Liva GD    Hyderabad  2012
# 4   4                          Hyundai i20 Magna       Mumbai  2014
#
#    kilometraje tipo de gas transmision tipo dueño      millage    motor  \
# 0        40929         CNG      Manual      First  32.26 km/kg   998 CC
# 1        54493      Petrol      Manual     Second    24.7 kmpl   796 CC
# 2        34000      Diesel      Manual      First   13.68 kmpl  2393 CC
# 3       139000      Diesel      Manual      First   23.59 kmpl  1364 CC
# 4        29000      Petrol      Manual      First    18.5 kmpl  1197 CC
#
#        poder  asientos      precio
# 0   58.2 bhp       4.0         NaN
# 1   47.3 bhp       5.0         NaN
# ...

# %%
datos.tail(5)
# Out:
#         id                                             nombre localizacion  \
# 1229  1229                  Volkswagen Vento Diesel Trendline    Hyderabad
# 1230  1230                             Volkswagen Polo GT TSI       Mumbai
# 1231  1231                             Nissan Micra Diesel XV      Kolkata
# 1232  1232                             Volkswagen Polo GT TSI         Pune
# 1233  1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...        Kochi
#
#        año  kilometraje tipo de gas transmision tipo dueño     millage  \
# 1229  2011        89411      Diesel      Manual      First  20.54 kmpl
# 1230  2015        59000      Petrol   Automatic      First  17.21 kmpl
# 1231  2012        28000      Diesel      Manual      First  23.08 kmpl
# 1232  2013        52262      Petrol   Automatic      Third   17.2 kmpl
# 1233  2014        72443      Diesel   Automatic      First   10.0 kmpl
#
#         motor      poder  asientos precio
# 1229  1598 CC  103.6 bhp       5.0    NaN
# ...

# %%
datos.to_csv(fichero)

# %%
datos.to_json(fichero)
